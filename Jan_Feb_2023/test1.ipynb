# %%
import pandas as pd

# %%
df = pd.read_csv('testing_dataset.csv', index_col=0)
print(df.shape)
df.head()
# Out:
# (15881, 44)
#                                       address  Avg min between sent tnx  \
# 0  0x8ab7404063ec4dbcfd4598215992dc3f8ec853d7                       0.0
# 1  0x1c74cff0376fb4031cd7492cd6db2d66c3f2c6b9                       0.0
# 2  0x06af07097c9eeb7fd685c692751d5c66db49c215                       0.0
# 3  0xc00e94cb662c3520282e6f5717214004a7f26888                       0.0
# 4  0xb3319f5d18bc0d84dd1b4825dcde5d5f7266d407                       0.0
#
#    Avg min between received tnx  Time Diff between first and_last (Mins)  \
# 0                   3287.708857                                 31664442
# 1                  30856.847650                                131489280
# 2                  21756.221050                                 93009370
# 3                    952.460123                                  9562025
# 4                   3644.096995                                 36142462
#
#    Sent_tnx  Received_tnx  NumberofCreated_Contracts  \
# 0         0          9632                          1
# 1         0          4261                          1
# 2         0          4276                          1
# 3         0          9781                          1
# 4         0          9919                          1
#
#    UniqueReceivedFrom_Addresses  UniqueSentTo_Addresses20  MinValueReceived  \
# 0                          2033                         0               0.0
# 1                          3652                         0               0.0
# 2                          1386                         0               0.0
# 3                          4302                         0               0.0
# 4                          3389                         0               0.0
#
#    ...  ERC20MaxVal_Rec  ERC20AvgVal_Rec  ERC20MinVal_Sent  \
# 0  ...     5.000000e+23     3.690000e+22               0.0
# 1  ...     5.000000e+16     0.000000e+00               0.0
# 2  ...     4.000000e+22     1.160000e+21               0.0
# 3  ...     1.211000e+21     2.540000e+19               0.0
# 4  ...     5.742887e+23     8.650000e+21               0.0
#
#            ERC20MaxVal_Sent  ERC20AvgVal_Sent  ERC20UniqSentTokenName  \
# 0                         0      0.000000e+00                       0
# 1                         0      0.000000e+00                       0
# 2  202651788858138416902420      4.040000e+21                       1
# 3                         0      0.000000e+00                       0
# 4               2.23225E+23      1.620000e+21                       2
#
#    ERC20UniqRecTokenName  ERC20MostSentTokenType  ERC20MostRecTokenType  FLAG
# 0                     19                       0              Akropolis     0
# 1                      1                       0          Wrapped Ether     0
# 2                      2          Dai Stablecoin         Dai Stablecoin     0
# 3                     18                       0               Compound     0
# 4                      2             Compound 0x                    ZRX     0
#
# [5 rows x 44 columns]

# %%
# Ommit first two columns (Adress)
df = df.iloc[:,1:]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15881 entries, 0 to 18068
# Data columns (total 43 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Avg min between sent tnx                          15881 non-null  float64
#  1   Avg min between received tnx                      15881 non-null  float64
#  2   Time Diff between first and_last (Mins)           15881 non-null  int64
#  3   Sent_tnx                                          15881 non-null  int64
#  4   Received_tnx                                      15881 non-null  int64
#  5   NumberofCreated_Contracts                         15881 non-null  int64
#  6   UniqueReceivedFrom_Addresses                      15881 non-null  int64
#  7   UniqueSentTo_Addresses20                          15881 non-null  int64
#  8   MinValueReceived                                  15881 non-null  float64
#  9   MaxValueReceived                                  15881 non-null  float64
#  10  AvgValueReceived5Average                          15881 non-null  float64
#  11  MinValSent                                        15881 non-null  float64
#  12  MaxValSent                                        15881 non-null  float64
#  13  AvgValSent                                        15881 non-null  float64
#  14  MinValueSentToContract                            15881 non-null  float64
#  15  MaxValueSentToContract                            15881 non-null  float64
#  16  AvgValueSentToContract                            15881 non-null  float64
#  17  TotalTransactions(IncludingTnxtoCreate_Contract)  15881 non-null  int64
#  18  TotalEtherSent                                    15881 non-null  float64
#  19  TotalEtherReceived                                15881 non-null  float64
#  20  TotalEtherSent_Contracts                          15881 non-null  float64
#  21  TotalEtherBalance                                 15881 non-null  object
#  22  TotalERC20Tnxs:                                   15881 non-null  int64
#  23  ERC20TotalEther_Received:                         15881 non-null  object
#  24  ERC20TotalEther_Sent:                             15881 non-null  object
#  25  ERC20TotalEtherSentContract:                      15881 non-null  object
#  26  ERC20UniqSent_Addr:                               15881 non-null  int64
#  27  ERC20UniqRec_Addr:                                15881 non-null  int64
#  28  ERC20UniqRecContractAddr:                         15881 non-null  int64
#  29  ERC20AvgTimeBetweenSent_Tnx                       15881 non-null  float64
#  30  ERC20AvgTimeBetweenRec_Tnx                        15881 non-null  float64
#  31  ERC20AvgTimeBetweenContract_Tnx                   15881 non-null  float64
#  32  ERC20MinVal_Rec                                   15881 non-null  float64
#  33  ERC20MaxVal_Rec                                   15881 non-null  float64
#  34  ERC20AvgVal_Rec                                   15881 non-null  float64
#  35  ERC20MinVal_Sent                                  15881 non-null  float64
#  36  ERC20MaxVal_Sent                                  15881 non-null  object
#  37  ERC20AvgVal_Sent                                  15881 non-null  float64
#  38  ERC20UniqSentTokenName                            15881 non-null  int64
#  39  ERC20UniqRecTokenName                             15881 non-null  int64
#  40  ERC20MostSentTokenType                            15874 non-null  object
#  41  ERC20MostRecTokenType                             15865 non-null  object
#  42  FLAG                                              15881 non-null  int64
# dtypes: float64(22), int64(14), object(7)
# memory usage: 5.3+ MB

# %%
# Turn object variables into 'category' dtype for more computation efficiency
categories = df.select_dtypes('O').columns.astype('category')
df[categories]
# Out:
#       TotalEtherBalance  ERC20TotalEther_Received:      ERC20TotalEther_Sent:  \
# 0                     0  1624147753951456392159898                          0
# 1                     0                      5E+16                          0
# 2                     0   250356191777770241947859  2012174199556976444377529
# 3                     0     2646219848935635501341                          0
# 4                     0  4011316252893124092128943   805324484693942838881506
# ...                 ...                        ...                        ...
# 18064   296860000000000                        0.0                        0.0
# 18065                 0                        0.0                        0.0
# 18066   815125917056000                        0.0                        0.0
# 18067                 0                        0.0                        0.0
# 18068                 0                        0.0                        0.0
#
#       ERC20TotalEtherSentContract:          ERC20MaxVal_Sent  \
# 0                    3200582512003                         0
# 1                                0                         0
# 2        1763818007779206202429670  202651788858138416902420
# 3             19510000004100000401                         0
# 4          18118926255770702992831               2.23225E+23
# ...                            ...                       ...
# 18064                        1e+16                       0.0
# 18065                          0.0                       0.0
# 18066                          0.0                       0.0
# 18067                          0.0                       0.0
# 18068                          0.0                       0.0
#
#       ERC20MostRecTokenType
# 0                 Akropolis
# 1             Wrapped Ether
# 2            Dai Stablecoin
# 3                  Compound
# 4                       ZRX
# ...                     ...
# 18064                     0
# 18065                     0
# 18066                     0
# 18067                     0
# 18068                     0
#
# [15881 rows x 6 columns]

# %%
# Inspect categoricals
for i in df[categories].columns:
    print(f'The categorical column --{i}-- has --{len(df[i].value_counts())}-- unique values')
# Out:
# The categorical column --TotalEtherBalance-- has --2139-- unique values
# The categorical column --ERC20TotalEther_Received:-- has --4218-- unique values
# The categorical column --ERC20TotalEther_Sent:-- has --2225-- unique values
# The categorical column --ERC20TotalEtherSentContract:-- has --2801-- unique values
# The categorical column --ERC20MaxVal_Sent-- has --1829-- unique values
# The categorical column --ERC20MostRecTokenType-- has --2417-- unique values

# %%
# Inspect numericals
numericals = df.select_dtypes(include=['float','int']).columns
df[numericals].describe()
# Out:
#        Avg min between sent tnx  Avg min between received tnx  \
# count              1.588100e+04                  1.588100e+04
# mean               1.120187e+05                  1.049521e+06
# std                1.393467e+06                  5.178569e+06
# min                0.000000e+00                  0.000000e+00
# 25%                0.000000e+00                  0.000000e+00
# 50%                0.000000e+00                  1.613119e+04
# 75%                0.000000e+00                  2.495181e+05
# max                7.991704e+07                  1.183291e+08
#
#        Time Diff between first and_last (Mins)      Sent_tnx  Received_tnx  \
# count                             1.588100e+04  15881.000000  15881.000000
# mean                              2.478137e+07     79.935709   1188.865185
# std                               3.971923e+07    756.749420   2817.660275
# min                               0.000000e+00      0.000000      0.000000
# 25%                               9.930000e+02      0.000000      1.000000
# 50%                               2.900190e+06      0.000000      8.000000
# 75%                               3.268264e+07      0.000000    206.000000
# max                               2.345687e+08  10000.000000  10000.000000
#
#        NumberofCreated_Contracts  UniqueReceivedFrom_Addresses  \
# count               15881.000000                   15881.00000
# mean                    2.608589                     329.50891
# std                    72.924876                    1032.45882
# min                     0.000000                       0.00000
# 25%                     1.000000                       1.00000
# 50%                     1.000000                       3.00000
# 75%                     1.000000                      36.00000
# max                  6410.000000                    9992.00000
#
#        UniqueSentTo_Addresses20  MinValueReceived  MaxValueReceived  ...  \
# count              15881.000000      1.588100e+04      1.588100e+04  ...
# mean                  18.521252      3.863202e+17      6.329780e+20  ...
# std                  265.058753      3.968903e+19      1.505050e+22  ...
# min                    0.000000      0.000000e+00      0.000000e+00  ...
# 25%                    0.000000      0.000000e+00      0.000000e+00  ...
# 50%                    0.000000      0.000000e+00      0.000000e+00  ...
# 75%                    0.000000      0.000000e+00      2.260000e+17  ...
# max                 7853.000000      5.000010e+21      7.895250e+23  ...
#
#        ERC20AvgTimeBetweenRec_Tnx  ERC20AvgTimeBetweenContract_Tnx  \
# count                1.588100e+04                     1.588100e+04
# mean                 1.336922e+06                     3.617135e+06
# std                  5.310510e+06                     1.643900e+07
# min                  0.000000e+00                     0.000000e+00
# 25%                  0.000000e+00                     0.000000e+00
# 50%                  0.000000e+00                     0.000000e+00
# 75%                  1.848571e+02                     0.000000e+00
# max                  1.208909e+08                     1.517945e+08
#
#        ERC20MinVal_Rec  ERC20MaxVal_Rec  ERC20AvgVal_Rec  ERC20MinVal_Sent  \
# count     1.588100e+04     1.588100e+04     1.588100e+04      1.588100e+04
# mean      1.184214e+73     1.026567e+74     3.719917e+72      7.579891e+25
# std       1.055159e+75     3.273456e+75     2.492630e+74      7.963107e+27
# min       0.000000e+00     0.000000e+00     0.000000e+00      0.000000e+00
# 25%       0.000000e+00     0.000000e+00     0.000000e+00      0.000000e+00
# 50%       0.000000e+00     0.000000e+00     0.000000e+00      0.000000e+00
# 75%       1.000000e+01     6.410256e+18     6.585000e+07      0.000000e+00
# max       9.402811e+76     1.157921e+77     2.890000e+76      1.000000e+30
#
#        ERC20AvgVal_Sent  ERC20UniqSentTokenName  ERC20UniqRecTokenName  \
# count      1.588100e+04            15881.000000           15881.000000
# mean       1.051571e+71                0.566715               2.617404
# std        1.112875e+73                3.535619              12.090729
# min        0.000000e+00                0.000000               0.000000
# 25%        0.000000e+00                0.000000               0.000000
# 50%        0.000000e+00                0.000000               0.000000
# 75%        0.000000e+00                0.000000               1.000000
# max        1.370000e+75              164.000000             512.000000
#
#                FLAG
# count  15881.000000
# mean       0.169322
# std        0.375048
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 36 columns]

# %%
# Filtering the features with 0 variance
no_var = df.var() == 0
print(df.var()[no_var])
print('\n')

# Drop features with 0 variance --- these features will not help in the performance of the model
df.drop(df.var()[no_var].index, axis = 1, inplace = True)
print(df.var())
print(df.shape)
# Out:
# Series([], dtype: float64)
#
#
# Avg min between sent tnx                             1.941751e+12
# Avg min between received tnx                         2.681758e+13
# Time Diff between first and_last (Mins)              1.577618e+15
# Sent_tnx                                             5.726697e+05
# Received_tnx                                         7.939209e+06
# NumberofCreated_Contracts                            5.318037e+03
# UniqueReceivedFrom_Addresses                         1.065971e+06
# UniqueSentTo_Addresses20                             7.025614e+04
# MinValueReceived                                     1.575219e+39
# MaxValueReceived                                     2.265175e+44
# AvgValueReceived5Average                             5.922313e+39
# MinValSent                                           3.981637e+43
# MaxValSent                                           1.461882e+44
# AvgValSent                                           3.990714e+43
# MinValueSentToContract                               8.919193e+45
# MaxValueSentToContract                               8.919193e+45
# AvgValueSentToContract                               8.916945e+45
# TotalTransactions(IncludingTnxtoCreate_Contract)     9.247993e+06
# TotalEtherSent                                       4.426753e+43
# TotalEtherReceived                                   2.547460e+41
# TotalEtherSent_Contracts                             8.919193e+45
# TotalERC20Tnxs:                                      4.004122e+04
# ERC20UniqSent_Addr:                                  5.749982e+03
# ERC20UniqRec_Addr:                                   2.513131e+03
# ERC20UniqRecContractAddr:                            3.289105e+02
# ERC20AvgTimeBetweenSent_Tnx                          1.263416e+13
# ERC20AvgTimeBetweenRec_Tnx                           2.820151e+13
# ERC20AvgTimeBetweenContract_Tnx                      2.702406e+14
# ERC20MinVal_Rec                                     1.113360e+150
# ERC20MaxVal_Rec                                     1.071551e+151
# ERC20AvgVal_Rec                                     6.213202e+148
# ERC20MinVal_Sent                                     6.341108e+55
# ERC20AvgVal_Sent                                    1.238491e+146
# ERC20UniqSentTokenName                               1.250060e+01
# ERC20UniqRecTokenName                                1.461857e+02
# FLAG                                                 1.406608e-01
# dtype: float64
# (15881, 43)
# C:\Users\Debasish\AppData\Local\Temp/ipykernel_4056/520906194.py:2: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   no_var = df.var() == 0
# C:\Users\Debasish\AppData\Local\Temp/ipykernel_4056/520906194.py:3: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df.var()[no_var])
# C:\Users\Debasish\AppData\Local\Temp/ipykernel_4056/520906194.py:7: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.drop(df.var()[no_var].index, axis = 1, inplace = True)
# C:\Users\Debasish\AppData\Local\Temp/ipykernel_4056/520906194.py:8: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df.var())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15881 entries, 0 to 18068
# Data columns (total 43 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Avg min between sent tnx                          15881 non-null  float64
#  1   Avg min between received tnx                      15881 non-null  float64
#  2   Time Diff between first and_last (Mins)           15881 non-null  int64
#  3   Sent_tnx                                          15881 non-null  int64
#  4   Received_tnx                                      15881 non-null  int64
#  5   NumberofCreated_Contracts                         15881 non-null  int64
#  6   UniqueReceivedFrom_Addresses                      15881 non-null  int64
#  7   UniqueSentTo_Addresses20                          15881 non-null  int64
#  8   MinValueReceived                                  15881 non-null  float64
#  9   MaxValueReceived                                  15881 non-null  float64
#  10  AvgValueReceived5Average                          15881 non-null  float64
#  11  MinValSent                                        15881 non-null  float64
#  12  MaxValSent                                        15881 non-null  float64
#  13  AvgValSent                                        15881 non-null  float64
#  14  MinValueSentToContract                            15881 non-null  float64
#  15  MaxValueSentToContract                            15881 non-null  float64
#  16  AvgValueSentToContract                            15881 non-null  float64
#  17  TotalTransactions(IncludingTnxtoCreate_Contract)  15881 non-null  int64
#  18  TotalEtherSent                                    15881 non-null  float64
#  19  TotalEtherReceived                                15881 non-null  float64
#  20  TotalEtherSent_Contracts                          15881 non-null  float64
#  21  TotalEtherBalance                                 15881 non-null  object
#  22  TotalERC20Tnxs:                                   15881 non-null  int64
#  23  ERC20TotalEther_Received:                         15881 non-null  object
#  24  ERC20TotalEther_Sent:                             15881 non-null  object
#  25  ERC20TotalEtherSentContract:                      15881 non-null  object
#  26  ERC20UniqSent_Addr:                               15881 non-null  int64
#  27  ERC20UniqRec_Addr:                                15881 non-null  int64
#  28  ERC20UniqRecContractAddr:                         15881 non-null  int64
#  29  ERC20AvgTimeBetweenSent_Tnx                       15881 non-null  float64
#  30  ERC20AvgTimeBetweenRec_Tnx                        15881 non-null  float64
#  31  ERC20AvgTimeBetweenContract_Tnx                   15881 non-null  float64
#  32  ERC20MinVal_Rec                                   15881 non-null  float64
#  33  ERC20MaxVal_Rec                                   15881 non-null  float64
#  34  ERC20AvgVal_Rec                                   15881 non-null  float64
#  35  ERC20MinVal_Sent                                  15881 non-null  float64
#  36  ERC20MaxVal_Sent                                  15881 non-null  object
#  37  ERC20AvgVal_Sent                                  15881 non-null  float64
#  38  ERC20UniqSentTokenName                            15881 non-null  int64
#  39  ERC20UniqRecTokenName                             15881 non-null  int64
#  40  ERC20MostSentTokenType                            15874 non-null  category
#  41  ERC20MostRecTokenType                             15865 non-null  object
#  42  FLAG                                              15881 non-null  int64
# dtypes: category(1), float64(22), int64(14), object(6)
# memory usage: 5.3+ MB

# %%
drop = ['total transactions (including tnx to create contract', 'total ether sent contracts', 'max val sent to contract', 'ERC20 avg val rec',
        'ERC20 avg val rec','ERC20 max val rec', 'ERC20 min val rec', 'ERC20 uniq rec contract addr', 'max val sent', 'ERC20 avg val sent',
        'ERC20 min val sent', 'ERC20 max val sent', 'Total ERC20 tnxs', 'avg value sent to contract', 'Unique Sent To Addresses',
        'Unique Received From Addresses', 'total ether received', 'ERC20 uniq sent token name', 'min value received', 'min val sent', 'ERC20 uniq rec addr' ]
df.drop(drop, axis=1, inplace=True)
